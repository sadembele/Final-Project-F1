# %%
import pandas as pd
import numpy as np

# %%
## Load in dataset

# %%
PIT = pd.read_csv('/Users/biddieb/Desktop/pitStops2021added.csv')

# %%
PIT
# Out:
#      raceId  driverId  stop  lap      time duration  milliseconds  \
# 0      1051         1     1   18  17:30:21   25.235         25235
# 1      1051         1     2   42  18:05:37   25.381         25381
# 2      1052         1     1   13  18:30:29   24.839         24839
# 3      1052         1     2   28  18:54:40   24.076         24076
# 4      1053         1     1   28  15:49:27   32.112         32112
# ..      ...       ...   ...  ...       ...      ...           ...
# 793    1071       854     3   11  14:20:29   41.173         41173
# 794    1071       854     4   29  14:44:54   25.597         25597
# 795    1071       854     5   61  15:26:09   24.627         24627
# 796    1073       854     1   10  17:18:55   22.124         22124
# 797    1073       854     2   52  18:23:42    22.07         22070
#
#      constructorId  grid position fastestLapTime fastestLapSpeed  engineType
# 0              131     1        1        01:25.1         227.633         NaN
# ...

# %%
## See all driverId values and frequencies

# %%
PIT.driverId.value_counts()
# Out:
# 1      47
# 841    46
# 20     43
# 815    43
# 830    43
# 853    42
# 842    42
# 4      41
# 852    40
# 854    40
# 822    39
# 846    39
# 847    39
# 817    38
# 832    37
# 844    37
# 849    37
# 840    35
# 8      35
# 839    33
# 9       2
# Name: driverId, dtype: int64

# %%
## Load in Dataset

# %%
RES = pd.read_csv('/Users/biddieb/Desktop/Formula 1 Final project/2021 data/results2021.csv')

# %%
## Made a new dictionary for driver constr (mapping) iloc(integer location)

# %%
driver_constr_dict = {RES.driverId.iloc[i]: RES.constructorId.iloc[i] for i in range(RES.shape[0])}

# %%
RES
# Out:
#      resultId  raceId  driverId  constructorId  number  grid position  \
# 0       25346    1051         1            131      44     1        1
# 1       25347    1051       830              9      33     7        2
# 2       25348    1051         4            214      14     3        3
# 3       25349    1051       815              9      11    11        4
# 4       25350    1051       839            214      31     9        5
# ..        ...     ...       ...            ...     ...   ...      ...
# 435     25401    1073       849              3       6    16       \N
# 436     25402    1073       841             51      99    14       \N
# 437     25403    1073       847              3      63    17       \N
# 438     25404    1073         8             51       7    18       \N
# 439     25405    1073       853            210       9    20       \N
#
#     positionText  positionOrder  points  laps       time milliseconds  \
# ...

# %%
driver_constr_dict
# Out:
# {1: 131,
#  830: 9,
#  4: 214,
#  815: 9,
#  839: 214,
#  840: 117,
#  832: 6,
#  844: 6,
#  846: 1,
#  20: 117,
#  842: 213,
#  817: 1,
#  852: 213,
#  8: 51,
#  841: 51,
#  854: 210,
#  847: 3,
#  853: 210,
#  849: 3,
#  822: 131,
#  9: 51}

# %%
## Check to see if value match

# %%
driver_constr_dict[815]
# Out:
# 9

# %%
## Create new column and go in driverId and apply the dictionary

# %%
PIT['constructorId'] = PIT.driverId.apply(lambda x: driver_constr_dict[x])

# %%
PIT
# Out:
#      raceId  driverId  stop  lap      time duration  milliseconds  \
# 0      1051         1     1   18  17:30:21   25.235         25235
# 1      1051         1     2   42  18:05:37   25.381         25381
# 2      1052         1     1   13  18:30:29   24.839         24839
# 3      1052         1     2   28  18:54:40   24.076         24076
# 4      1053         1     1   28  15:49:27   32.112         32112
# ..      ...       ...   ...  ...       ...      ...           ...
# 793    1071       854     3   11  14:20:29   41.173         41173
# 794    1071       854     4   29  14:44:54   25.597         25597
# 795    1071       854     5   61  15:26:09   24.627         24627
# 796    1073       854     1   10  17:18:55   22.124         22124
# 797    1073       854     2   52  18:23:42    22.07         22070
#
#      constructorId  grid position fastestLapTime fastestLapSpeed  engineType
# 0              131     1        1        01:25.1         227.633         NaN
# ...

# %%
## Create engineType from constructorId

# %%
constrId_dict = {9:0,131:1,6:2,1:1,213:0,214:3,117:1,3:1,51:2,210:2}

# %%
constrId_dict
# Out:
# {9: 0, 131: 1, 6: 2, 1: 1, 213: 0, 214: 3, 117: 1, 3: 1, 51: 2, 210: 2}

# %%
constrId_dict[213]
# Out:
# 0

# %%
## Apply dictionary to constructorId to get engineTypePIT.

# %%
PIT['engineType'] = PIT.constructorId.apply(lambda x: constrId_dict[x])

# %%
PIT
# Out:
#      raceId  driverId  stop  lap      time duration  milliseconds  \
# 0      1051         1     1   18  17:30:21   25.235         25235
# 1      1051         1     2   42  18:05:37   25.381         25381
# 2      1052         1     1   13  18:30:29   24.839         24839
# 3      1052         1     2   28  18:54:40   24.076         24076
# 4      1053         1     1   28  15:49:27   32.112         32112
# ..      ...       ...   ...  ...       ...      ...           ...
# 793    1071       854     3   11  14:20:29   41.173         41173
# 794    1071       854     4   29  14:44:54   25.597         25597
# 795    1071       854     5   61  15:26:09   24.627         24627
# 796    1073       854     1   10  17:18:55   22.124         22124
# 797    1073       854     2   52  18:23:42    22.07         22070
#
#      constructorId  grid position fastestLapTime fastestLapSpeed  engineType
# 0              131     1        1        01:25.1         227.633           1
# ...

# %%
RES
# Out:
#      resultId  raceId  driverId  constructorId  number  grid position  \
# 0       25346    1051         1            131      44     1        1
# 1       25347    1051       830              9      33     7        2
# 2       25348    1051         4            214      14     3        3
# 3       25349    1051       815              9      11    11        4
# 4       25350    1051       839            214      31     9        5
# ..        ...     ...       ...            ...     ...   ...      ...
# 435     25401    1073       849              3       6    16       \N
# 436     25402    1073       841             51      99    14       \N
# 437     25403    1073       847              3      63    17       \N
# 438     25404    1073         8             51       7    18       \N
# 439     25405    1073       853            210       9    20       \N
#
#     positionText  positionOrder  points  laps       time milliseconds  \
# ...
